# %%
spotify_template = """
<div>
    <script>

        document.write('<canvas id="Week""" + str(i) + """></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/Spotify/csv/week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.rank;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#D8B655";
                if (d.RU == "RU") return "#E55759";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#D8B655" ? "українські виконавці" : c === "#E55759" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d.artist_names + " - " + d.track_name,
                                            "К-сть стримів: " + d.streams
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [50, 100, 150];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 198) {
                                            return 200;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "Сходинка в чарті"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""

# %%
youtube_template = """
<div>
    <script>

        document.write('<canvas id="Week""" + str(i) + """></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/YouTube Music/csv/week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.rank;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#D8B655";
                if (d.RU == "RU") return "#E55759";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#D8B655" ? "українські виконавці" : c === "#E55759" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d.artist_names + " - " + d.track_name,
                                            "К-сть стримів: " + d.streams
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [50, 100, 150];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 198) {
                                            return 200;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "Сходинка в чарті"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 spotify_template = """
#       2 <div>
#       3     <script>
#       4
# ----> 5         document.write('<canvas id="Week""" + str(i) + """></canvas>');
#       6
#       7         // load the csv file and convert it into an array of objects
#       8         d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/YouTube Music/csv/week""" + str(i) + """.csv").then(makeChart);
#       9
#      10         // define a function to make the chart
#      11         function makeChart(data) {
#      12             // extract the labels from the first column of the csv
#      13             const labels = data.map(function (d) {
#      14                 return d.rank;
#      15             });
#      16
#      17             // set the data values to 1 for all bars
#      18             const values = data.map(function (d) {
#      19                 return 1;
#      20             });
#      21
#      22             // extract the colors from the third column of the csv
#      23             const colors = data.map(function (d) {
#      24                 if (d.UA == "UA") return "#D8B655";
#      25                 if (d.RU == "RU") return "#E55759";
#      26                 if (d.OTHER == "OTHER") return "#4198D7";
#      27             });
#      28
#      29             // create a bar chart with chart js
#      30             new Chart("Week""" + str(i) + """",
#      31                 {
#      32                     type: "bar",
#      33                     data: {
#      34                         labels: labels,
#      35                         datasets: [{
#      36                             data: values,
#      37                             backgroundColor: colors
#      38                         }]
#      39                     },
#      40
#      41                     options: {
#      42                         plugins: {
#      43                             legend: {
#      44                                 display: true,
#      45                                 position: "top",
#      46                                 align: "center",
#      47                                 labels: {
#      48                                     // Use circle instead of line for legend items
#      49                                     // usePointStyle: true,
#      50
#      51                                     // Generate labels with custom text
#      52                                     generateLabels: function (chart) {
#      53                                         // get the unique colors from the data
#      54                                         const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
#      55                                         // return an array of legend items
#      56                                         return colors.map(c => {
#      57                                             // get the category associated with the color
#      58                                             const category = c === "#D8B655" ? "українські виконавці" : c === "#E55759" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
#      59                                             //
#      60                                             const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
#      61                                             // return an object with the text and fillStyle properties
#      62                                             return {
#      63                                                 text: `${category} (${count})`,
#      64                                                 fillStyle: c
#      65                                             };
#      66                                         });
#      67                                     }
#      68                                 }
#      69                             },
#      70
#      71                             tooltip: {
#      72                                 callbacks: {
#      73                                     label: function (context) {
#      74                                         // get the index of the hovered bar
#      75                                         const index = context.dataIndex;
#      76                                         // get the corresponding row from the csv
#      77                                         const d = data[index];
#      78                                         // return an array with the artist, track name and number of streams
#      79                                         return [
#      80                                             d.artist_names + " - " + d.track_name,
#      81                                             "К-сть стримів: " + d.streams
#      82                                         ];
#      83                                     }
#      84                                 },
#      85                                 yAlign: 'top',
#      86                             }
#      87                         },
#      88
#      89                         scales: {
#      90                             y: {
#      91                                 ticks: {
#      92                                     beginAtZero: true,
#      93                                     display: false
#      94                                 }
#      95                             },
#      96                             x: {
#      97                                 ticks: {
#      98                                     beginAtZero: true,
#      99                                     callback: function (value) {
#     100                                         var values = [50, 100, 150];
#     101                                         if (values.includes(value)) {
#     102                                             return value;
#     103                                         } else if (value < 1) {
#     104                                             return 0;
#     105                                         } else if (value > 198) {
#     106                                             return 200;
#     107                                         }
#     108                                     }
#     109                                 },
#     110                                 title: {
#     111                                     display: true,
#     112                                     text: "Сходинка в чарті"
#     113                                 }
#     114                             }
#     115                         }
#     116                     }
#     117                 });
#     118         }
#     119     </script>
#     120 </div>
#     121 """
#
# NameError: name 'i' is not defined

# %%
import os

# %%
os.getcwd()
# Out:
# 'z:\\OneDrive\\University\\Dyplom\\dyplom csv and plots\\Apple Music\\plots'

# %%
os.chdir('..')

# %%
cd "dyplom csv and plots"
# Out:
# z:\OneDrive\University\Dyplom\dyplom csv and plots

# %%
# generate files in ragnge with the selected content
def generate_spotify(path, upper_range):
    os.chdir(path)
    for i in range(1, upper_range + 1):
        with open("week" + str(i) + ".html", "w") as file:
            file.write(
                """
<div>
    <script>

        document.write('<canvas id="Week""" + str(i) + """"></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/Spotify/csv/week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.rank;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#FFE53E";
                if (d.RU == "RU") return "#F06663";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#FFE53E" ? "українські виконавці" : c === "#F06663" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d.artist_names + " - " + d.track_name,
                                            "К-сть стримів: " + d.streams
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [50, 100, 150];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 198) {
                                            return 200;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "Сходинка в чарті"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
            )

# %%
# year23
def generate_spotify23(path, upper_range):
    os.chdir(path)
    for i in range(1, upper_range + 1):
        with open("23week" + str(i) + ".html", "w") as file:
            file.write(
                """
<div>
    <script>

        document.write('<canvas id="23Week""" + str(i) + """"></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/Spotify/csv/23week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.rank;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#FFE53E";
                if (d.RU == "RU") return "#F06663";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("23Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#FFE53E" ? "українські виконавці" : c === "#F06663" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d.artist_names + " - " + d.track_name,
                                            "К-сть стримів: " + d.streams
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [50, 100, 150];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 198) {
                                            return 200;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "Сходинка в чарті"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
            )

# %%
def generate_general_spotify():
    generate_spotify('Spotify/plots', 52)
    os.chdir('..')
    os.chdir('..')
    generate_spotify23('Spotify/plots', 8)

# %%
generate_general_spotify()

# %%
# generate files in ragnge with the selected content
def generate_youtube(path, upper_range):
    os.chdir(path)
    for i in range(1, upper_range + 1):
        with open("week" + str(i) + ".html", "w") as file:
            file.write(
                """
<div>
    <script>

        document.write('<canvas id="yt_Week""" + str(i) + """"></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/YouTube Music/csv/week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.Rank;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#FFE53E";
                if (d.RU == "RU") return "#F06663";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("yt_Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#FFE53E" ? "українські виконавці" : c === "#F06663" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d["Artist Names"] + " - " + d["Track Name"],
                                            "К-сть стримів: " + d.Views
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [25, 50, 75];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 98) {
                                            return 100;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "Сходинка в чарті"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
            )

# %%
# year23
def generate_youtube23(path, upper_range):
    os.chdir(path)
    for i in range(1, upper_range + 1):
        with open("23week" + str(i) + ".html", "w") as file:
            file.write(
                """
<div>
    <script>

        document.write('<canvas id="yt_23Week""" + str(i) + """"></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/YouTube Music/csv/23week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.Rank;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#FFE53E";
                if (d.RU == "RU") return "#F06663";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("yt_23Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#FFE53E" ? "українські виконавці" : c === "#F06663" ? "російські виконавці" : c === "#4198D7" ? "виконавці інших країн" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d["Artist Names"] + " - " + d["Track Name"],
                                            "К-сть стримів: " + d.Views
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [25, 50, 75];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 98) {
                                            return 100;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "Сходинка в чарті"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
            )

# %%
def generate_general_youtube():
    generate_youtube('YouTube Music/plots', 52)
    os.chdir('..')
    os.chdir('..')
    generate_youtube23('YouTube Music/plots', 8)

# %%
generate_general_youtube()

# %%
# generate files in ragnge with the selected content
def generate_apple(path, upper_range):
    os.chdir(path)
    for i in range(1, upper_range + 1):
        with open("week" + str(i) + ".html", "w", encoding="utf-8") as file:
            file.write(
                """
<div>
    <script>

        document.write('<canvas id="appl_Week""" + str(i) + """"></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/Apple Music/csv/week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.Position;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#FFE53E";
                if (d.RU == "RU") return "#F06663";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("appl_Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#FFE53E" ? "ukrainians_u" : c === "#F06663" ? "russians_r" : c === "#4198D7" ? "other_o" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d.Artist + " - " + d.Song
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [25, 50, 75];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 98) {
                                            return 100;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "schodynka"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
            )

# %%
# year23
def generate_apple23(path, upper_range):
    os.chdir(path)
    for i in range(1, upper_range + 1):
        with open("23week" + str(i) + ".html", "w", encoding="utf-8") as file:
            file.write(
                """
<div>
    <script>

        document.write('<canvas id="appl_23Week""" + str(i) + """"></canvas>');

        // load the csv file and convert it into an array of objects
        d3.csv("https://raw.githubusercontent.com/xhelgo/dyplom-csv/main/Apple Music/csv/23week""" + str(i) + """.csv").then(makeChart);

        // define a function to make the chart
        function makeChart(data) {
            // extract the labels from the first column of the csv
            const labels = data.map(function (d) {
                return d.Position;
            });

            // set the data values to 1 for all bars
            const values = data.map(function (d) {
                return 1;
            });

            // extract the colors from the third column of the csv
            const colors = data.map(function (d) {
                if (d.UA == "UA") return "#FFE53E";
                if (d.RU == "RU") return "#F06663";
                if (d.OTHER == "OTHER") return "#4198D7";
            });

            // create a bar chart with chart js      
            new Chart("appl_23Week""" + str(i) + """",
                {
                    type: "bar",
                    data: {
                        labels: labels,
                        datasets: [{
                            data: values,
                            backgroundColor: colors
                        }]
                    },

                    options: {
                        plugins: {
                            legend: {
                                display: true,
                                position: "top",
                                align: "center",
                                labels: {
                                    // Use circle instead of line for legend items
                                    // usePointStyle: true,

                                    // Generate labels with custom text
                                    generateLabels: function (chart) {
                                        // get the unique colors from the data
                                        const colors = [...new Set(chart.data.datasets[0].backgroundColor)];
                                        // return an array of legend items
                                        return colors.map(c => {
                                            // get the category associated with the color
                                            const category = c === "#FFE53E" ? "ukrainians_u" : c === "#F06663" ? "russians_r" : c === "#4198D7" ? "other_o" : "UNKNOWN";
                                            //
                                            const count = chart.data.datasets[0].data.filter((d, i) => chart.data.datasets[0].backgroundColor[i] === c).length;
                                            // return an object with the text and fillStyle properties
                                            return {
                                                text: `${category} (${count})`,
                                                fillStyle: c
                                            };
                                        });
                                    }
                                }
                            },

                            tooltip: {
                                callbacks: {
                                    label: function (context) {
                                        // get the index of the hovered bar
                                        const index = context.dataIndex;
                                        // get the corresponding row from the csv
                                        const d = data[index];
                                        // return an array with the artist, track name and number of streams
                                        return [
                                            d.Artist + " - " + d.Song
                                        ];
                                    }
                                },
                                yAlign: 'top',
                            }
                        },

                        scales: {
                            y: {
                                ticks: {
                                    beginAtZero: true,
                                    display: false
                                }
                            },
                            x: {
                                ticks: {
                                    beginAtZero: true,
                                    callback: function (value) {
                                        var values = [25, 50, 75];
                                        if (values.includes(value)) {
                                            return value;
                                        } else if (value < 1) {
                                            return 0;
                                        } else if (value > 98) {
                                            return 100;
                                        }
                                    }
                                },
                                title: {
                                    display: true,
                                    text: "schodynka"
                                }
                            }
                        }
                    }
                });
        }
    </script>
</div>
"""
            )

# %%
def generate_general_apple():
    generate_apple('Apple Music/plots', 52)
    os.chdir('..')
    os.chdir('..')
    generate_apple23('Apple Music/plots', 8)

# %%
generate_general_apple()
